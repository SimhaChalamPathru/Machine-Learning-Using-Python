# %% [markdown]
# # One- Sample t-test:

# %%
"""A company claims that on an average it takes only 40 hours to
process any purchase order. Based on the data given below, can you validate
the claim? The data is given in PO_Processing.csv
"""

#import pandas as pd
#data = pd.read_csv("https://raw.githubuser")

       # OR
from google.colab import files
uploaded = files.upload()
import io
import pandas as pd
data = pd.read_csv(io.BytesIO(uploaded['PO_Processing.csv']))
data
# Out:
#      <input type="file" id="files-1d8f334e-03e3-4271-92a1-8aa3073086d3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1d8f334e-03e3-4271-92a1-8aa3073086d3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
PT = data.Processing_Time
PT
# Out:
# 0     49
# 1     46
# 2     56
# 3     56
# 4     68
#       ..
# 95    36
# 96    37
# 97    12
# 98    42
# 99    72
# Name: Processing_Time, Length: 100, dtype: int64

# %%
# Performing one-sample t-test
import scipy
from scipy import stats 
stats.ttest_1samp(PT,40)
# Out:
# TtestResult(statistic=3.703149778826719, pvalue=0.0003505232879117337, df=99)

# %% [markdown]
# # Two sample t-test

# %%
"""A super market chain has introduced a promotional activity in its
selected outlets in the city to increase the sales volume. Based on the data
given below, check whether the promotional activity resulted in increasing the
sales. The outlets where promotional activity introduced are denoted by 1 and
others by 2? The data is given in Sales_Promotion.csv
"""
# Out:
# 'A super market chain has introduced a promotional activity in its\nselected outlets in the city to increase the sales volume. Based on the data\ngiven below, check whether the promotional activity resulted in increasing the\nsales. The outlets where promotional activity introduced are denoted by 1 and\nothers by 2? The data is given in Sales_Promotion.csv\n'

# %%
from google.colab import files
uploaded = files.upload()
import io
import pandas as pd
from scipy import stats
data=pd.read_csv(io.BytesIO(uploaded['Sales_Promotion.csv']))
data
# Out:
#      <input type="file" id="files-1edcfe8a-4264-4deb-b8e7-2d175262ed1f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1edcfe8a-4264-4deb-b8e7-2d175262ed1f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Reading Variables

s1 = data.Sales_Out1
s2 = data.Sales_Out2
s1,s2
# Out:
# (0     1217
#  1     1416
#  2     1381
#  3     1413
#  4     1800
#  5     1724
#  6     1310
#  7     1616
#  8     1941
#  9     1792
#  10    1453
#  11    1780
#  Name: Sales_Out1, dtype: int64, 0     1731
#  1     1420
#  2     1065
#  3     1612
#  4     1361
#  5     1259
#  6     1470
#  7      622
#  8     1711
#  9     2315
#  10    1180
#  11    1515
#  Name: Sales_Out2, dtype: int64)

# %%
# 2 sample t test

stats.ttest_ind(s1,s2)
# Out:
# Ttest_indResult(statistic=0.9625184533861655, pvalue=0.3462502310190171)

# %% [markdown]
# # Paired t test:

# %%
"""The manager of a fleet of automobiles is testing two brands of radial tires. He
assigns one tire of each brand at random to the two rear wheels of eight cars
and runs the cars until the tire wear out. Is both brands have equal mean life?
The data in kilometers is given in tires.csv"""
# Out:
# 'The manager of a fleet of automobiles is testing two brands of radial tires. He\nassigns one tire of each brand at random to the two rear wheels of eight cars\nand runs the cars until the tire wear out. Is both brands have equal mean life?\nThe data in kilometers is given in tires.csv'

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d9efe27f-af50-47c3-bb1c-1dcc8fbf078f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d9efe27f-af50-47c3-bb1c-1dcc8fbf078f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
import pandas as pd
from scipy import stats
data = pd.read_csv(io.BytesIO(uploaded['Tires.csv']))
data
# Out:
#    Brand_1  Brand_2
# 0    36925    34318
# 1    45300    42280
# 2    36240    35500
# 3    32100    31950
# 4    37210    38015
# 5    48360    47800
# 6    38200    37810
# 7    33500    33215

# %%
# Reading the variable

b1 = data.Brand_1
b2 = data.Brand_2

b1,b2
# Out:
# (0    36925
#  1    45300
#  2    36240
#  3    32100
#  4    37210
#  5    48360
#  6    38200
#  7    33500
#  Name: Brand_1, dtype: int64, 0    34318
#  1    42280
#  2    35500
#  3    31950
#  4    38015
#  5    47800
#  6    37810
#  7    33215
#  Name: Brand_2, dtype: int64)

# %%
# Paried t test

stats.ttest_rel(b1,b2)
# Out:
# TtestResult(statistic=1.903932074206155, pvalue=0.09863400041070944, df=7)

# %% [markdown]
# # Normality Tests

# %%
"""The processing times of purchase orders is given in
PO_Processing.csv. Is processing time normally distributed?
"""
# Out:
# 'The processing times of purchase orders is given in\nPO_Processing.csv. Is processing time normally distributed?\n'

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4ed957bd-2d4d-4cfc-8c4d-e074a96bd5d3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4ed957bd-2d4d-4cfc-8c4d-e074a96bd5d3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
import pandas as pd
from scipy import stats
import matplotlib.pyplot as myplot
data = pd.read_csv(io.BytesIO(uploaded['PO_Processing.csv']))
data
# Out:
#     Processing_Time
# 0                49
# 1                46
# 2                56
# 3                56
# 4                68
# ..              ...
# 95               36
# 96               37
# 97               12
# 98               42
# 99               72
#
# [100 rows x 1 columns]

# %%
PT = data.Processing_Time
PT
# Out:
# 0     49
# 1     46
# 2     56
# 3     56
# 4     68
#       ..
# 95    36
# 96    37
# 97    12
# 98    42
# 99    72
# Name: Processing_Time, Length: 100, dtype: int64

# %% [markdown]
# ### Normality Checking using Q-Q plot

# %%
stats.probplot(PT,plot=myplot)
myplot.show()

# %% [markdown]
# ### Normality Checking using Shapiro - wilk test

# %%
stats.mstats.normaltest(PT)
# Out:
# NormaltestResult(statistic=0.3396526182225922, pvalue=0.8438113662149449)

# %% [markdown]
# # Analysis of variance

# %%
# One Way ANOVA


"""An electronics and home appliance chain suspect the location of shelves
where television sets are kept will influence the sales revenue. The data on
sales revenue in lakhs from the television sets when they are kept at
different locations inside the store are given in sales revenue data file. The
location is denoted as 1:front, 2: middle & 3: rear. Verify the doubt? The data
is given in Sales_Revenue_Anova.csv."""
# Out:
# 'An electronics and home appliance chain suspect the location of shelves\nwhere television sets are kept will influence the sales revenue. The data on\nsales revenue in lakhs from the television sets when they are kept at\ndifferent locations inside the store are given in sales revenue data file. The\nlocation is denoted as 1:front, 2: middle & 3: rear. Verify the doubt? The data\nis given in Sales_Revenue_Anova.csv.'

# %%
# Importing Packages 

from google.colab import files
import io
import pandas as pd
from scipy import stats
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm

# %%
# import data

uploaded = files.upload()
data=pd.read_csv(io.BytesIO(uploaded['Sales_Revenue_Anova.csv']))
data
sales=data.Sales_Revenue
location = data.Location
# Out:
#      <input type="file" id="files-2a568a8b-aea0-4a46-993c-90edcbf87fbb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2a568a8b-aea0-4a46-993c-90edcbf87fbb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Computing ANOVA table

mymodel = ols('sales~C(location)',data).fit()
mymodel
anova_table = anova_lm(mymodel)
anova_table
# Out:
#                df     sum_sq   mean_sq          F    PR(>F)
# C(location)   2.0  11.082715  5.541358  20.099493  0.000057
# Residual     15.0   4.135446  0.275696        NaN       NaN

# %%
#location wise means

sales.groupby(location).mean()
# Out:
# Location
# 1    1.867500
# 2    3.788750
# 3    2.591667
# Name: Sales_Revenue, dtype: float64

# %%
# Box plot location Wise

import matplotlib.pyplot as plt
data.boxplot(column='Sales_Revenue',by='Location')
myplot.show()
